# %%
import pandas as pd

# %% [markdown]
# # Read Data

# %%
df = pd.read_csv('data/survey_results_public.csv',index_col = 'Respondent' )
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
pd.set_option('display.max_rows',400) # set number of rows/columns to be displayed

# %% [markdown]
# ## From dictionaray to DataFrame
#
# ### Dict = { Keys( column names ) : Values( this ca be a list or numeric values that will get added as rows to the corrosponding column )}

# %%
person = {
    "name" : ["Pranav" ],
    
    "surname" : ["Kulkarni"]
}

# %%
person
# Out:
# {'name': ['Pranav'], 'surname': ['Kulkarni']}

# %%
import pandas as pd

# %%
person_df = pd.DataFrame(person)

# %%
person_df
# Out:
#      name   surname
# 0  Pranav  Kulkarni

# %%
people = {
    "name" : ["Pranav" , "Pratik" , "Shivani" ],
    
    "surname" : ["Kulkarni" , "Kulkarni" , "Jog" ],
    
    "mail" : ["pranav@thinkxl" , "pratik@thinkxl" , "shivani@thinkxl"] ,
    
    "Birthplace" : ["Nashik" , "Omerga"  ,"Pune "]
}

# %%
people['Birthplace']
# Out:
# ['Nashik', 'Omerga', 'Pune ']

# %%
people_df = pd.DataFrame(people)

# %%
people_df
# Out:
#       name   surname             mail Birthplace
# 0   Pranav  Kulkarni   pranav@thinkxl     Nashik
# 1   Pratik  Kulkarni   pratik@thinkxl     Omerga
# 2  Shivani       Jog  shivani@thinkxl      Pune

# %%
people_df['Birthplace']
# Out:
# 0    Nashik
# 1    Omerga
# 2     Pune
# Name: Birthplace, dtype: object

# %%
people_df.count()
# Out:
# name          3
# surname       3
# mail          3
# Birthplace    3
# dtype: int64

# %% [markdown]
# # slicing and iloc , loc
#
#
# ### df.iloc[ start_from_row : end at row,start_from_col : end at col    ]
# ### df.iloc[row_number/row_numbers]
#
# iloc uses the index intergers for slicing the dictionary for both rows and columns
# can access all columns of a row if we only mention row numbers.
#
#
#
#
#
#
# ### df.loc[list of row names, list of column names]
# loc uses column names and row names(name of a person if the is set as an index or a specific date)

# %%
df.iloc[0:10,2:6]
# Out:
#              Age Age1stCode CompFreq  CompTotal
# Respondent
# 1            NaN         13  Monthly        NaN
# 2            NaN         19      NaN        NaN
# 3            NaN         15      NaN        NaN
# 4           25.0         18      NaN        NaN
# 5           31.0         16      NaN        NaN
# 6            NaN         14      NaN        NaN
# 7            NaN         18  Monthly        NaN
# 8           36.0         12   Yearly   116000.0
# 9           30.0         20      NaN        NaN
# 10          22.0         14   Yearly    25000.0

# %% [markdown]
# Can also send the list of intergers as input first list for rows second for columns
#
# ### df.iloc [ [indices of the rows], [indices of the cols] ]

# %%
df.iloc[[0,1]]
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             CompTotal  ConvertedComp         Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            CurrencySymbol  ...                  SurveyEase  \
# Respondent                 ...
# 1                     EUR  ...  Neither easy nor difficult
# 2                     GBP  ...                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# ...

# %%
df.iloc[[0,1] , 5]
# Out:
# Respondent
# 1   NaN
# 2   NaN
# Name: CompTotal, dtype: float64

# %%
df.iloc[[0,1] , [7, 5]]
# Out:
#                    Country  CompTotal
# Respondent
# 1                  Germany        NaN
# 2           United Kingdom        NaN

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64461 entries, 1 to 65112
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    64162 non-null  object
#  1   Hobbyist                      64416 non-null  object
#  2   Age                           45446 non-null  float64
#  3   Age1stCode                    57900 non-null  object
#  4   CompFreq                      40069 non-null  object
#  5   CompTotal                     34826 non-null  float64
#  6   ConvertedComp                 34756 non-null  float64
#  7   Country                       64072 non-null  object
#  8   CurrencyDesc                  45472 non-null  object
#  9   CurrencySymbol                45472 non-null  object
#  10  DatabaseDesireNextYear        44070 non-null  object
#  11  DatabaseWorkedWith            49537 non-null  object
# ...

# %%
df.loc[[1,2],["CompFreq" ,"ConvertedComp"]]
# Out:
#            CompFreq  ConvertedComp
# Respondent
# 1           Monthly            NaN
# 2               NaN            NaN

# %% [markdown]
# ### set indec if you want to change the current df you have make inplace = True or you can create a new df.

# %%
people_df.set_index('mail')
# people_df.set_index('mail' ,inplace = True) for making permanent change to df
# Out:
#                     name   surname Birthplace
# mail
# pranav@thinkxl    Pranav  Kulkarni     Nashik
# pratik@thinkxl    Pratik  Kulkarni     Omerga
# shivani@thinkxl  Shivani       Jog      Pune

# %%
people_df
# Out:
#       name   surname             mail Birthplace
# 0   Pranav  Kulkarni   pranav@thinkxl     Nashik
# 1   Pratik  Kulkarni   pratik@thinkxl     Omerga
# 2  Shivani       Jog  shivani@thinkxl      Pune

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %% [markdown]
# # Filtering
#
# To make things readeable we can either create a filter seperatly and apply it to the df.
#
# ### filter = (whatever condition you want)
#
#       ### filter = (df[columns]   operation (>,<,==,and,or,not)    values to compare)
# ### df[filter] (this will give the output df when the filter is applied)
#
#
# We can directly write the filter in the "df[]" itself if it is not too complex to understand the results will be same
#
# ### if you print the filter then you will a list of True and False values.

# %%
filter_ = (people_df['surname'] == 'Jog')

# %%
filter_
# Out:
# 0    False
# 1    False
# 2     True
# Name: surname, dtype: bool

# %%
people_df[filter_]
# Out:
#       name surname             mail Birthplace
# 2  Shivani     Jog  shivani@thinkxl      Pune

# %%
people_df[people_df['surname'] == 'Kulkarni']
# Out:
#      name   surname            mail Birthplace
# 0  Pranav  Kulkarni  pranav@thinkxl     Nashik
# 1  Pratik  Kulkarni  pratik@thinkxl     Omerga

# %% [markdown]
# Now with a bigger data set

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %% [markdown]
# Below is the example of appling filter for getting people with salary more than any specific amount.
#
# We are taking out only the 4 columns of our interest using df.loc

# %%
high_salary = (df['ConvertedComp'] > 1000000)

# %%
df.loc[high_salary ,['Age', 'Country','YearsCode','ConvertedComp','LanguageWorkedWith']]
# Out:
#              Age             Country           YearsCode  ConvertedComp  \
# Respondent
# 18          32.0       United States                  19      1260000.0
# 57          44.0       United States                  33      1620000.0
# 65          34.0       United States                  21      1176000.0
# 123         26.0       United States                   8      2000000.0
# 125         41.0       United States                  11      2000000.0
# 193         29.0       United States                  13      2000000.0
# 196         23.0       United States                   8      1920000.0
# 281         26.0       United States                  10      1104000.0
# 503         34.0       United States                  13      1500000.0
# 665         24.0       United States                   4      2000000.0
# 699         39.0       United States                   5      2000000.0
# 724          NaN       United States                   3      2000000.0
# ...

# %%
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %% [markdown]
# Filters with strings are mentioned below like name of the conutry or languege developer is using in his profession
#
# we can combine the above menioned 2 filters and get the developers who uses a specific languege from a specific country.
#
# ## filter_1 & filter_2

# %%
country = ['India' , 'Nomadic']
filt = df['Country'].isin(country)

# %%
df.loc[filt,'Country']
# Out:
# Respondent
# 7        India
# 22       India
# 58       India
# 63       India
# 149      India
#          ...
# 54757    India
# 55407    India
# 62464    India
# 62954    India
# 64236    India
# Name: Country, Length: 8434, dtype: object

# %%
new_filt = high_salary & filt

# %%
df.loc[new_filt]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 2260                           I am a developer by profession      Yes  37.0
# 36976       I am not primarily a developer, but I write co...       No   NaN
# 37655                          I am a developer by profession       No   NaN
# 46711                          I am a developer by profession      Yes   NaN
#
#                       Age1stCode CompFreq     CompTotal  ConvertedComp  \
# Respondent
# 2260                          10  Monthly  1.100000e+05      1320000.0
# 36976                         20   Yearly  1.600000e+06      1600000.0
# 37655                         15  Monthly  1.500000e+05      1800000.0
# 46711       Younger than 5 years   Yearly  1.000000e+56      2000000.0
#
#             Country          CurrencyDesc CurrencySymbol  ...  \
# Respondent                                                ...
# 2260        Nomadic  United States dollar            USD  ...
# ...

# %%
langauge_filt = df['LanguageWorkedWith'].str.contains('Python',na = False)

# %% [markdown]
# ### using more than one filter
#
#     filt = (df['column name']   contionational operator comparision value   value to compare with) and/or ((df['column name']   contionational operator comparision value   value to compare with))
#
#     filt = (df["Country"] == 'India') and/or (df["Salary"] > 10000000)
#
#     df[filt] for complete dataframe
#
#     df.loc[filt,list of Columns we want info from]

# %%
salary_laguege = langauge_filt & high_salary

# %%
df.loc[salary_laguege , ['Age', 'Country','YearsCode','ConvertedComp','LanguageWorkedWith']]
# Out:
#              Age        Country           YearsCode  ConvertedComp  \
# Respondent
# 123         26.0  United States                   8      2000000.0
# 125         41.0  United States                  11      2000000.0
# 665         24.0  United States                   4      2000000.0
# 818         40.0  United States                  25      2000000.0
# 1076        48.0  United States                  38      1440000.0
# 1117        35.0  United States                  23      2000000.0
# 1193        30.0  United States                  11      2000000.0
# 1387        30.0  United States                  10      1356000.0
# 1413        25.0  United States                  13      2000000.0
# 1629        36.0  United States                  17      2000000.0
# 1793        27.0  United States                  12      2000000.0
# 2093        55.0  United States                  10      2000000.0
# 2135        26.0  United States                   8      2000000.0
# ...

# %% [markdown]
# ## Negation of the filters
#
#     filt = (df['column name']   contionational operator comparision value   value to compare with) and/or ((df['column name']   contionational operator comparision value   value to compare with))
#
#     filt = (df["Country"] == 'India') and/or (df["Salary"] > 10000000)
#
#     df[~filt] for complete dataframe
#
#     df.loc[~filt,list of Columns we want info from]
#
# ### adding the tilda operator in front of the filter will give all the values other than the output of filter

# %%
df.loc[~salary_laguege , ['Age', 'Country','YearsCode','ConvertedComp','LanguageWorkedWith']]
# Out:
#              Age             Country YearsCode  ConvertedComp  \
# Respondent
# 1            NaN             Germany        36            NaN
# 2            NaN      United Kingdom         7            NaN
# 3            NaN  Russian Federation         4            NaN
# 4           25.0             Albania         7            NaN
# 5           31.0       United States        15            NaN
# ...          ...                 ...       ...            ...
# 64858        NaN       United States        10            NaN
# 64867        NaN             Morocco       NaN            NaN
# 64898        NaN            Viet Nam       NaN            NaN
# 64925        NaN              Poland       NaN            NaN
# 65112        NaN               Spain       NaN            NaN
#
#                                            LanguageWorkedWith
# Respondent
# 1                                      C#;HTML/CSS;JavaScript
# 2                                            JavaScript;Swift
# ...

# %% [markdown]
# # Update data in rows and cols

# %%
people_df.columns = [x.upper() for x in people_df.columns]

# %%
people_df.columns = ['NAME_PERSON', 'SURNAME_PERSON', 'EMAIL_PERSON','BIRTHPLACE_PERSON'  ]

# %%
people_df
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON
# 0      Pranav       Kulkarni   pranav@thinkxl            Nashik
# 1      Pratik       Kulkarni   pratik@thinkxl            Omerga
# 2     Shivani            Jog  shivani@thinkxl             Pune

# %%
people_df.columns = people_df.columns.str.replace('_' ,' ')

# %%
people_df
# Out:
#   NAME PERSON SURNAME PERSON     EMAIL PERSON BIRTHPLACE PERSON
# 0      Pranav       Kulkarni   pranav@thinkxl            Nashik
# 1      Pratik       Kulkarni   pratik@thinkxl            Omerga
# 2     Shivani            Jog  shivani@thinkxl             Pune

# %%
people_df.columns = people_df.columns.str.replace(' ' ,'_')

# %%
people_df
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON
# 0      Pranav       Kulkarni   pranav@thinkxl            Nashik
# 1      Pratik       Kulkarni   pratik@thinkxl            Omerga
# 2     Shivani            Jog  shivani@thinkxl             Pune

# %% [markdown]
# ## df.rename
#
#     df.rename(columns = {key : value})
#
#     dictionary should contain key as current column name we have and value as the name we want that column to have this method also has the inpalce argument so if we want change to be perment then we can have inplace = True

# %%
people_df.loc[2,'SURNAME_PERSON'] = 'Kulkarni'

# %%
people_df
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON
# 0      Pranav       Kulkarni   pranav@thinkxl            Nashik
# 1      Pratik       Kulkarni   pratik@thinkxl            Omerga
# 2     Shivani       Kulkarni  shivani@thinkxl             Pune

# %%
people_df.loc[2,['SURNAME_PERSON','EMAIL_PERSON','BIRTHPLACE_PERSON']] = ['Jog','jog@thinkxl','Nashik']

# %%
people_df
# Out:
#   NAME_PERSON SURNAME_PERSON    EMAIL_PERSON BIRTHPLACE_PERSON
# 0      Pranav       Kulkarni  pranav@thinkxl            Nashik
# 1      Pratik       Kulkarni  pratik@thinkxl            Omerga
# 2     Shivani            Jog     jog@thinkxl            Nashik

# %% [markdown]
# people_df.at[row_name , col_name] can also be used

# %%
# using filter to get values to be changed does not work

filt = (people_df['EMAIL_PERSON']=='jog@thinkxl')
people_df[filt]['SURNAME_PERSON']
# Out:
# 2    Jog
# Name: SURNAME_PERSON, dtype: object

# %%
people_df[filt]['EMAIL_PERSON'] = 'shivani@thinkxl'
# Out:
# /home/pranav/imapala/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
people_df #change did not happen
# Out:
#   NAME_PERSON SURNAME_PERSON    EMAIL_PERSON BIRTHPLACE_PERSON
# 0      Pranav       Kulkarni  pranav@thinkxl            Nashik
# 1      Pratik       Kulkarni  pratik@thinkxl            Omerga
# 2     Shivani            Jog     jog@thinkxl            Nashik

# %%
people_df.loc[filt,'EMAIL_PERSON']= 'shivani@thinkxl'

# %%
people_df #it works with loc or iloc
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON
# 0      Pranav       Kulkarni   pranav@thinkxl            Nashik
# 1      Pratik       Kulkarni   pratik@thinkxl            Omerga
# 2     Shivani            Jog  shivani@thinkxl            Nashik

# %%
people_df['EMAIL_PERSON'] = people_df['EMAIL_PERSON'].str.upper()

# %%
people_df
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON
# 0      Pranav       Kulkarni   PRANAV@THINKXL            Nashik
# 1      Pratik       Kulkarni   PRATIK@THINKXL            Omerga
# 2     Shivani            Jog  SHIVANI@THINKXL            Nashik

# %% [markdown]
# # Updating data  multiple rows at once
#
# ## apply - used for calling a function on our values it can either work on data frame or  a series object behaviour is a bit different in both cases.
#
#
# ## map
# ## applymap - Only works for dataframes Series objects don't have applymap
# ## replace

# %% [markdown]
# ## Apply
# ### On series
#
#     df['column name'].apply(function you want to apply)
#
#     eg.
#     1.(to check the length of our email ids)
#
#     people_df['EMAIL_PERSON'].apply(len)
#     2.to make ids lower case
#
#     def update_email(email):
#         return email.lower()
#     people_df['EMAIL_PERSON'].apply(update_email)
#
#     #don't put "()" we dont want execute it here just pass it as a function.
#
# ### On dataframe
#
#     df.apply(function)
#
#     here the function will get applied to Series in the dataframes that is either a row or a columns depending on the choice of the axis. default axis is row so all functions get applied to columns since axis of the columns is rows and vice versa for rows

# %%
def update_email(email):
        return email.lower()
people_df['EMAIL_PERSON'] = people_df['EMAIL_PERSON'].apply(update_email)
people_df
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON
# 0      Pranav       Kulkarni   pranav@thinkxl            Nashik
# 1      Pratik       Kulkarni   pratik@thinkxl            Omerga
# 2     Shivani            Jog  shivani@thinkxl            Nashik

# %%
people_df['EMAIL_PERSON'] = people_df['EMAIL_PERSON'].apply(lambda x: x.upper())
people_df
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON
# 0      Pranav       Kulkarni   PRANAV@THINKXL            Nashik
# 1      Pratik       Kulkarni   PRATIK@THINKXL            Omerga
# 2     Shivani            Jog  SHIVANI@THINKXL            Nashik

# %% [markdown]
# ##  In example below It will apply to ONLY columns(axis = rows) NOT all values. Note axis of traversing columns is rows and default axis is rows

# %%
people_df.apply(len)
# Out:
# NAME_PERSON          3
# SURNAME_PERSON       3
# EMAIL_PERSON         3
# BIRTHPLACE_PERSON    3
# dtype: int64

# %%
people_df.apply(len,axis = 'columns') # it will apply to ONLY rows NOT all values
# Out:
# 0    4
# 1    4
# 2    4
# dtype: int64

# %%
people_df.apply(pd.Series.min) # applied on columns
# Out:
# NAME_PERSON                  Pranav
# SURNAME_PERSON                  Jog
# EMAIL_PERSON         PRANAV@THINKXL
# BIRTHPLACE_PERSON            Nashik
# dtype: object

# %%
people_df.apply(lambda x : x.min())
# Out:
# NAME_PERSON                  Pranav
# SURNAME_PERSON                  Jog
# EMAIL_PERSON         PRANAV@THINKXL
# BIRTHPLACE_PERSON            Nashik
# dtype: object

# %% [markdown]
# ## Apply map
#
# Works for DataFrames only
#     df.applymap(function you want to apply to each element)

# %%
people_df.applymap(len)
# Out:
#    NAME_PERSON  SURNAME_PERSON  EMAIL_PERSON  BIRTHPLACE_PERSON
# 0            6               8            14                  6
# 1            6               8            14                  6
# 2            7               3            15                  6

# %%
people_df.applymap(str.lower)
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON
# 0      pranav       kulkarni   pranav@thinkxl            nashik
# 1      pratik       kulkarni   pratik@thinkxl            omerga
# 2     shivani            jog  shivani@thinkxl            nashik

# %% [markdown]
# ## Map
#
# Works only for Series objects you cannot use it for the dataframe directly.if you want to make the changes permnent then use df[col] = df[col].map({})
# eg.
#
#     df[column name].map({'values you want to change' : 'the changed values to apper'})
#
#     df['NAME_PERSON'].map({'Pranav':'Sunil','Pratik':'Madhuri'})
#
# ### it will introduce nan values in the Series for which you have not mentioned the change so keep it in mind

# %%
people_df['NAME_PERSON'].map({'Pranav':'Sunil','Pratik':'Madhuri'})
# Out:
# 0      Sunil
# 1    Madhuri
# 2        NaN
# Name: NAME_PERSON, dtype: object

# %% [markdown]
# ## Replace
#
# Works same as map does not introduce the nan values just finds and replaces what we have mentioned in the dictionary
# if you want to make the changes permnent then use df[col] = df[col].map({})

# %%
people_df['NAME_PERSON'].replace({'Pranav':'Sunil','Pratik':'Madhuri'})
# Out:
# 0      Sunil
# 1    Madhuri
# 2    Shivani
# Name: NAME_PERSON, dtype: object

# %%
df.rename(columns = {'ConvertedComp':'Salary_USD'} , inplace = True)

# Use inpalce = True only after the confirmation that the 
# changes you wanted
# have taken place correctly

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'Salary_USD', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
# Use map to make yes to True and No to False

df['Hobbyist'].map({'Yes' : True , 'No' : False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4         True
# 5         True
#          ...
# 64858     True
# 64867     True
# 64898     True
# 64925     True
# 65112     True
# Name: Hobbyist, Length: 64461, dtype: object

# %% [markdown]
# # Add/Remove rows and columns From df
#
#
# ## ADD columns
#     df['New column'] = df['column_1'] + ' ' + df['column_2']
#     df['New column'] = list of values
#
#
# ## REMOVE columns
#     df.drop(column name)
#
# ## ROWS
#     df.append()

# %%
people_df['FULL_NAME'] = people_df['NAME_PERSON'] +' '+ people_df['SURNAME_PERSON']

# %%
people_df
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON  \
# 0      Pranav       Kulkarni   PRANAV@THINKXL            Nashik
# 1      Pratik       Kulkarni   PRATIK@THINKXL            Omerga
# 2     Shivani            Jog  SHIVANI@THINKXL            Nashik
#
#          FULL_NAME
# 0  Pranav Kulkarni
# 1  Pratik Kulkarni
# 2      Shivani Jog

# %%
people_df['AGE'] = [25,29,29]

# %%
people_df
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON  \
# 0      Pranav       Kulkarni   PRANAV@THINKXL            Nashik
# 1      Pratik       Kulkarni   PRATIK@THINKXL            Omerga
# 2     Shivani            Jog  SHIVANI@THINKXL            Nashik
#
#          FULL_NAME  AGE
# 0  Pranav Kulkarni   25
# 1  Pratik Kulkarni   29
# 2      Shivani Jog   29

# %%
people_df.drop(columns = ['EMAIL_PERSON']) # ALSO HAS INPLACE
# Out:
#   NAME_PERSON SURNAME_PERSON BIRTHPLACE_PERSON        FULL_NAME  AGE
# 0      Pranav       Kulkarni            Nashik  Pranav Kulkarni   25
# 1      Pratik       Kulkarni            Omerga  Pratik Kulkarni   29
# 2     Shivani            Jog            Nashik      Shivani Jog   29

# %%
people_df['FULL_NAME'].str.split(' ',expand=True)

# people_df['col_1','col_1'] = people_df['FULL_NAME'].str.split(' ',expand=True)
# Out:
#          0         1
# 0   Pranav  Kulkarni
# 1   Pratik  Kulkarni
# 2  Shivani       Jog

# %%
# Uncomment this to see a error if we don't use ignor_index
#people_df.append({'NAME_PERSON':'Purva'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-e8f7d77b866f> in <module>
# ----> 1 people_df.append({'NAME_PERSON':'Purva'})
#
# ~/imapala/lib/python3.6/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7709             if isinstance(other, dict):
#    7710                 if not ignore_index:
# -> 7711                     raise TypeError("Can only append a dict if ignore_index=True")
#    7712                 other = Series(other)
#    7713             if other.name is None and not ignore_index:
#
# TypeError: Can only append a dict if ignore_index=True

# %%
people_df.append({'NAME_PERSON':'Purva'}, ignore_index = True)
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON  \
# 0      Pranav       Kulkarni   PRANAV@THINKXL            Nashik
# 1      Pratik       Kulkarni   PRATIK@THINKXL            Omerga
# 2     Shivani            Jog  SHIVANI@THINKXL            Nashik
# 3       Purva            NaN              NaN               NaN
#
#          FULL_NAME   AGE
# 0  Pranav Kulkarni  25.0
# 1  Pratik Kulkarni  29.0
# 2      Shivani Jog  29.0
# 3              NaN   NaN

# %%
people_df
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON  \
# 0      Pranav       Kulkarni   PRANAV@THINKXL            Nashik
# 1      Pratik       Kulkarni   PRATIK@THINKXL            Omerga
# 2     Shivani            Jog  SHIVANI@THINKXL            Nashik
#
#          FULL_NAME  AGE
# 0  Pranav Kulkarni   25
# 1  Pratik Kulkarni   29
# 2      Shivani Jog   29

# %%
people = {
    "NAME_PERSON" : ["Sunil" , "Madhuri"],
    
    "SURNAME_PERSON" : ["Kulkarni" , "Kulkarni"],
    
    "Birthplace" : ["Kopargao" , "Omerga" ],
    
    "AGE" : ["60","52"],
}

# %%
df2 = pd.DataFrame(people)

# %%
people_df = people_df.append(df2,ignore_index = True) # does not have inplace

# %%
people_df
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON  \
# 0      Pranav       Kulkarni   PRANAV@THINKXL            Nashik
# 1      Pratik       Kulkarni   PRATIK@THINKXL            Omerga
# 2     Shivani            Jog  SHIVANI@THINKXL            Nashik
# 3       Sunil       Kulkarni              NaN               NaN
# 4     Madhuri       Kulkarni              NaN               NaN
#
#          FULL_NAME AGE Birthplace
# 0  Pranav Kulkarni  25        NaN
# 1  Pratik Kulkarni  29        NaN
# 2      Shivani Jog  29        NaN
# 3              NaN  60   Kopargao
# 4              NaN  52     Omerga

# %%
people_df.drop(index =4) # has inplace
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON  \
# 0      Pranav       Kulkarni   PRANAV@THINKXL            Nashik
# 1      Pratik       Kulkarni   PRATIK@THINKXL            Omerga
# 2     Shivani            Jog  SHIVANI@THINKXL            Nashik
# 3       Sunil       Kulkarni              NaN               NaN
#
#          FULL_NAME AGE Birthplace
# 0  Pranav Kulkarni  25        NaN
# 1  Pratik Kulkarni  29        NaN
# 2      Shivani Jog  29        NaN
# 3              NaN  60   Kopargao

# %%
people_df.drop(index = people_df[people_df['SURNAME_PERSON'] != 'Kulkarni'].index)


#this is using the filtering we can define the filter outside as well
# Out:
#   NAME_PERSON SURNAME_PERSON    EMAIL_PERSON BIRTHPLACE_PERSON  \
# 0      Pranav       Kulkarni  PRANAV@THINKXL            Nashik
# 1      Pratik       Kulkarni  PRATIK@THINKXL            Omerga
# 3       Sunil       Kulkarni             NaN               NaN
# 4     Madhuri       Kulkarni             NaN               NaN
#
#          FULL_NAME AGE Birthplace
# 0  Pranav Kulkarni  25        NaN
# 1  Pratik Kulkarni  29        NaN
# 3              NaN  60   Kopargao
# 4              NaN  52     Omerga

# %% [markdown]
# # Sorting data
#
# ### it has "inplace argument"

# %%
people_df
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON  \
# 0      Pranav       Kulkarni   PRANAV@THINKXL            Nashik
# 1      Pratik       Kulkarni   PRATIK@THINKXL            Omerga
# 2     Shivani            Jog  SHIVANI@THINKXL            Nashik
# 3       Sunil       Kulkarni              NaN               NaN
# 4     Madhuri       Kulkarni              NaN               NaN
#
#          FULL_NAME AGE Birthplace
# 0  Pranav Kulkarni  25        NaN
# 1  Pratik Kulkarni  29        NaN
# 2      Shivani Jog  29        NaN
# 3              NaN  60   Kopargao
# 4              NaN  52     Omerga

# %%
people_df.sort_values(by = 'NAME_PERSON' , ascending = False)
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON  \
# 3       Sunil       Kulkarni              NaN               NaN
# 2     Shivani            Jog  SHIVANI@THINKXL            Nashik
# 1      Pratik       Kulkarni   PRATIK@THINKXL            Omerga
# 0      Pranav       Kulkarni   PRANAV@THINKXL            Nashik
# 4     Madhuri       Kulkarni              NaN               NaN
#
#          FULL_NAME AGE Birthplace
# 3              NaN  60   Kopargao
# 2      Shivani Jog  29        NaN
# 1  Pratik Kulkarni  29        NaN
# 0  Pranav Kulkarni  25        NaN
# 4              NaN  52     Omerga

# %% [markdown]
# ## if in one column 2 values are same then we can pass list of the columns according to the preferences we want

# %%
people_df.sort_values(by = ['NAME_PERSON','AGE'] , ascending = False)
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON  \
# 3       Sunil       Kulkarni              NaN               NaN
# 2     Shivani            Jog  SHIVANI@THINKXL            Nashik
# 1      Pratik       Kulkarni   PRATIK@THINKXL            Omerga
# 0      Pranav       Kulkarni   PRANAV@THINKXL            Nashik
# 4     Madhuri       Kulkarni              NaN               NaN
#
#          FULL_NAME AGE Birthplace
# 3              NaN  60   Kopargao
# 2      Shivani Jog  29        NaN
# 1  Pratik Kulkarni  29        NaN
# 0  Pranav Kulkarni  25        NaN
# 4              NaN  52     Omerga

# %% [markdown]
# ## we can also send list of booleans to the ascending parameter that list will correspond to the list of columns and we can use ascending/descending as required

# %%
people_df.sort_values(by = ['NAME_PERSON','AGE'] , ascending = [False ,True] , inplace = True)

# %%
people_df
# Out:
#   NAME_PERSON SURNAME_PERSON     EMAIL_PERSON BIRTHPLACE_PERSON  \
# 3       Sunil       Kulkarni              NaN               NaN
# 2     Shivani            Jog  SHIVANI@THINKXL            Nashik
# 1      Pratik       Kulkarni   PRATIK@THINKXL            Omerga
# 0      Pranav       Kulkarni   PRANAV@THINKXL            Nashik
# 4     Madhuri       Kulkarni              NaN               NaN
#
#          FULL_NAME AGE Birthplace
# 3              NaN  60   Kopargao
# 2      Shivani Jog  29        NaN
# 1  Pratik Kulkarni  29        NaN
# 0  Pranav Kulkarni  25        NaN
# 4              NaN  52     Omerga

# %% [markdown]
# ## Sort index

# %%
people_df.sort_index(inplace = True)

# %% [markdown]
# ### For sorting a single column data df['column name'].sort_values() can also be used

# %%
df.sort_values(by = 'Country',inplace =True)

# %%
df['Country'].head(200)
# Out:
# Respondent
# 8631     Afghanistan
# 25001    Afghanistan
# 58171    Afghanistan
# 42668    Afghanistan
# 51509    Afghanistan
# 37951    Afghanistan
# 28374    Afghanistan
# 7616     Afghanistan
# 43966    Afghanistan
# 62698    Afghanistan
# 51532    Afghanistan
# 36574    Afghanistan
# 43946    Afghanistan
# 65381    Afghanistan
# 38672    Afghanistan
# 35753    Afghanistan
# 43808    Afghanistan
# 37159    Afghanistan
# 44555    Afghanistan
# 35687    Afghanistan
# 37605    Afghanistan
# 44556    Afghanistan
# 23798    Afghanistan
# 42188    Afghanistan
# 65456    Afghanistan
# 44697    Afghanistan
# 60507    Afghanistan
# 898      Afghanistan
# 51900    Afghanistan
# 35179    Afghanistan
# 2932     Afghanistan
# 55019    Afghanistan
# 15422    Afghanistan
# 46844    Afghanistan
# 45481    Afghanistan
# 51862    Afghanistan
# 63848    Afghanistan
# 35656    Afghanistan
# 33878    Afghanistan
# 26575    Afghanistan
# 37601    Afghanistan
# 9839     Afghanistan
# ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'Salary_USD', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df[['Country','Salary_USD']].head(200)
# Out:
#                 Country  Salary_USD
# Respondent
# 8631        Afghanistan         NaN
# 25001       Afghanistan         NaN
# 58171       Afghanistan         NaN
# 42668       Afghanistan         NaN
# 51509       Afghanistan     20220.0
# 37951       Afghanistan         NaN
# 28374       Afghanistan    130000.0
# 7616        Afghanistan         NaN
# 43966       Afghanistan         NaN
# 62698       Afghanistan         NaN
# 51532       Afghanistan         NaN
# 36574       Afghanistan         NaN
# 43946       Afghanistan         NaN
# 65381       Afghanistan   1000000.0
# 38672       Afghanistan    231192.0
# 35753       Afghanistan       780.0
# 43808       Afghanistan         NaN
# 37159       Afghanistan         NaN
# 44555       Afghanistan         NaN
# 35687       Afghanistan         NaN
# 37605       Afghanistan         NaN
# 44556       Afghanistan         NaN
# 23798       Afghanistan         NaN
# 42188       Afghanistan         NaN
# ...

# %%
df.sort_values(by = ['Country','Salary_USD'],ascending = [True,False],inplace =True)

# %%
df[['Country','Salary_USD']].head(200)
# Out:
#                 Country  Salary_USD
# Respondent
# 65381       Afghanistan   1000000.0
# 65456       Afghanistan   1000000.0
# 62788       Afghanistan   1000000.0
# 38672       Afghanistan    231192.0
# 28374       Afghanistan    130000.0
# 63848       Afghanistan     23328.0
# 9839        Afghanistan     23328.0
# 51862       Afghanistan     20950.0
# 51509       Afghanistan     20220.0
# 44484       Afghanistan     18660.0
# 15422       Afghanistan     18000.0
# 2932        Afghanistan     16335.0
# 26540       Afghanistan     13992.0
# 57269       Afghanistan     10884.0
# 26775       Afghanistan      8016.0
# 30568       Afghanistan      5448.0
# 30522       Afghanistan      4668.0
# 28811       Afghanistan      4509.0
# 34969       Afghanistan      4356.0
# 26857       Afghanistan      2328.0
# 33878       Afghanistan      1860.0
# 35753       Afghanistan       780.0
# 18049       Afghanistan       109.0
# 35295       Afghanistan         0.0
# ...

# %% [markdown]
# ## largest/smallest from df

# %%
df['Salary_USD'].nlargest(10)
# Out:
# Respondent
# 54263    2000000.0
# 5725     2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 1793     2000000.0
# 3072     2000000.0
# 3045     2000000.0
# 1413     2000000.0
# 3261     2000000.0
# Name: Salary_USD, dtype: float64

# %%
df.nlargest(10,'Salary_USD')
# Out:
#                                 MainBranch Hobbyist   Age  \
# Respondent
# 54263       I am a developer by profession      Yes  29.0
# 5725        I am a developer by profession       No  26.0
# 43430       I am a developer by profession      Yes  33.0
# 59279       I am a developer by profession      Yes   NaN
# 46711       I am a developer by profession      Yes   NaN
# 1793        I am a developer by profession      Yes  27.0
# 3072        I am a developer by profession      Yes  32.0
# 3045        I am a developer by profession      Yes  35.0
# 1413        I am a developer by profession      Yes  25.0
# 3261        I am a developer by profession      Yes  34.0
#
#                       Age1stCode CompFreq     CompTotal  Salary_USD  \
# Respondent
# 54263                         10   Weekly  7.000000e+04   2000000.0
# 5725                          14  Monthly  1.800000e+05   2000000.0
# 43430                         17  Monthly  1.710000e+05   2000000.0
# ...

# %%
df.nsmallest(10,'Salary_USD')
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 35295       I am a developer by profession      Yes   NaN         13  Monthly
# 47357       I am a developer by profession      Yes   NaN          5   Weekly
# 27135       I am a developer by profession       No   NaN         16   Yearly
# 6054        I am a developer by profession      Yes  38.0         15   Yearly
# 60292       I am a developer by profession      Yes   NaN         12   Yearly
# 38813       I am a developer by profession       No   NaN         18  Monthly
# 8470        I am a developer by profession      Yes   NaN          5  Monthly
# 41006       I am a developer by profession      Yes  22.0         17   Yearly
# 15493       I am a developer by profession       No  44.0         17  Monthly
# 57369       I am a developer by profession       No  44.0         18  Monthly
#
#             CompTotal  Salary_USD      Country        CurrencyDesc  \
# Respondent
# ...
